# %% [markdown]
# # Práctica Clase 2

# %% [markdown]
# 1) Abrir el archivo "Emisiones_CO2.csv" y cargar sus datos en un diccionario.

# %%
import os
archivo = open('Emisiones_CO2.csv', 'r', encoding='latin-1')

# %%
archivo = open(r'C:\Users\Usuario\OneDrive\Escritorio\CURSADO DATA CIENCE\Clase 02\Emisiones_CO2.csv','r', encoding='latin-1')

# %%
dicc_emisiones = {  'cod_pais' : [], #0
                    'nom_pais' : [],#1
                    'region' : [],#2
                    'anio' : [],#3
                    'co2' : [],#4
                    'co2_percapita' : []}#5

# %%
next(archivo) #saco los cabezales
for linea in archivo:
    linea = linea.strip()                       # saca /n
    campo = linea.split('|')                    # corta por | y lo guarda en una lista
    dicc_emisiones['cod_pais'].append(campo[0])
    dicc_emisiones['nom_pais'].append(campo[1])
    dicc_emisiones['region'].append(campo[2])
    dicc_emisiones[ 'anio'].append(campo[3])
    dicc_emisiones[ 'co2'].append(campo[4])
    dicc_emisiones[ 'co2_percapita'].append(campo[5])

# %%
dicc_emisiones['anio']

# %%
archivo.close()

# %% [markdown]
# 2) a) ¿Cuántas variables hay? <br>
# b) ¿Qué tipos de datos usar para cada una? <br>
# c) ¿Qué tipo de variables son? <br>
# d) ¿Hay valores faltantes? <br>
# e) ¿Cuál es el total de emisiones de CO2 para 'América Latina y Caribe' en el año 2010?

# %% [markdown]
# a) 6

# %% [markdown]
# b)cualitativo 1,2,3

# %%
#valores faltantes

for clave in dicc_emisiones:
    for elemento in dicc_emisiones[clave]:
        if not elemento:
            print('falta un elemento en',clave)

# %%
#normalizacion

def Normalizacion(lista):
    for indice, elemento in enumerate(lista):
        if elemento:
            elemento=elemento.replace('.', '')
            elemento=elemento.replace(',', '.')
            elemento = float(elemento)
        else: elemento = None
        lista [indice]= elemento
    return lista

# %%
def Normalizacion_anio(lista): # cambiamos punto por nada y coma por punto
    for indice, elemento in enumerate(lista):
        if elemento:
            elemento=elemento.replace('.', '')
           
            elemento = int(elemento)
        else: elemento = None
        lista [indice]= elemento
    return lista

# %%
#cambio los valores en estos campos
dicc_emisiones['co2']= Normalizacion(dicc_emisiones['co2'])
dicc_emisiones['co2_percapita']= Normalizacion(dicc_emisiones['co2_percapita'])

# %%
dicc_emisiones['anio']= Normalizacion_anio(dicc_emisiones['anio'])

# %%
type(dicc_emisiones['co2'][26])

# %%
type(dicc_emisiones['anio'][1])

# %%
filtro_region='América Latina y Caribe'
filtro_anio=2010
emisiones=0

# %%
#Total de emisiones
for i in range (len(dicc_emisiones['region'])):
    if dicc_emisiones['region'][i]==filtro_region and dicc_emisiones['anio'][i]==filtro_anio and dicc_emisiones['co2'][i]!=None:
        emisiones +=dicc_emisiones['co2'][i]
print (f'Las emisiones en {filtro_region} en {filtro_anio} fueron de {emisiones}')
